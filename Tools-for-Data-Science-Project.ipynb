# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Will Nobles** Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy using mathematical tools and programming to gain insights into how the world works. I also love data visualization.*

# %% [markdown]
# ### The below code adds two integers.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ***
# ## List
# 1. Item one
#     1. subitem one
# 2. Item two
#     1. subitem one
#     2. subitem two
# 3. Item three
#     1. subitem one
#     2. subitem two
#     3. subitem three
# ***
# ## Table
# | Fruit | Quantity | Price |
# | ----- | :------: | ----- |
# | Banana| 3        | 2.50  |
# | Apple | 4        | 3.00  |
# | Orange| 2        | 1.50  |
#
# ***
# ## Hyperlink
# [This is my Github](https://github.com/wnobles)
# ***
# ## Image
# ![Practice%20Logo_OrangeBlack.png](attachment:Practice%20Logo_OrangeBlack.png)
# ***
# ## Strikethrough
# ~~NOT~~ getting the hang of this
# ***
